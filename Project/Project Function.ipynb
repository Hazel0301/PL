# %%
import requests
import time
import json

api_key = "AIzaSyClIgd7cVjwrKTfScgSlZ70qaV9j1EBNvQ"# Google Places API 金鑰
location = "25.026291669509572,121.52751914993078"# 地點的經緯度
radius = 1000 # 半徑

# %%
# 使用者介面選擇餐廳或咖啡廳
place_type = input("請選擇要搜尋的類型（1: 餐廳, 2: 咖啡廳）：")
if place_type == "1":
    types = "restaurant"
elif place_type == "2":
    types = "cafe"
else:
    print("無效的選擇，請重新執行程式並選擇有效的類型。")
    exit()
# Out:
# 請選擇要搜尋的類型（1: 餐廳, 2: 咖啡廳）：1

# %%
# 使用者介面選擇價格等級
price_level = input("請選擇價格等級（1: 最便宜, 2: 中等價位, 3: 最昂貴）：")
# Out:
# 請選擇價格等級（1: 最便宜, 2: 中等價位, 3: 最昂貴）：2

# %%
# 使用者介面選擇店家評價區間
min_rating = input("請輸入最低評價（範圍：0-5）：")
max_rating = input("請輸入最高評價（範圍：0-5）：")
# Out:
# 請輸入最低評價（範圍：0-5）：4
# 請輸入最高評價（範圍：0-5）：5

# %%
# 設定輸出檔案名稱
output_file = "places_function.json"

# 構建 Google Places API 的請求 URL
url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?key={api_key}&location={location}&radius={radius}&type={types}&language=zh-TW"

# 設定最大資料數量
max_data_count = 20

# 儲存符合條件的資料的列表
filtered_data = []

# 發送 API 請求並取得資料
while len(filtered_data) < max_data_count:
    response = requests.get(url)
    result = response.json()

    if "results" in result:
        new_data = result["results"]
        for place in new_data:
            if "price_level" in place and place["price_level"] == int(price_level):
                if "rating" in place and float(min_rating) <= place["rating"] <= float(max_rating):
                    filtered_data.append(place)

    if "next_page_token" in result:
        next_page_token = result["next_page_token"]
        url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?key={api_key}&pagetoken={next_page_token}"

    if len(filtered_data) >= max_data_count:
        break

    time.sleep(2)

# 將資料儲存為 JSON 檔案
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(filtered_data, f, ensure_ascii=False, indent=4)

print(f"已儲存 {len(filtered_data)} 筆資料至 {output_file} 檔案。")
# Out:
# 已儲存 23 筆資料至 places_function.json 檔案。

# %%
print("搜尋結果：\n")
# 印出店家及資料
for index, place in enumerate(data, 1):
    print(f"店家 {index}")
    print("名稱:", place["name"])
    print("地址:", place.get("vicinity", "未提供"))
    print("評分:", place.get("rating", "未提供"))
    print("價格等級:", place.get("price_level", "未提供"))
    print("-" * 20)
# Out:
# 搜尋結果：
#
# 店家 1
# 名稱: 紅蜻蜓食事處
# 地址: 大安區永康街35之1號
# 評分: 3.8
# 價格等級: 2
# --------------------
# 店家 2
# 名稱: Focus kitchen肯恩廚房
# 地址: 大安區信義路二段198巷6號
# 評分: 4.3
# 價格等級: 2
# --------------------
# 店家 3
# 名稱: 莫宰羊-大安台大店
# 地址: 大安區新生南路三段28號
# 評分: 4.2
# 價格等級: 2
# --------------------
# 店家 4
# 名稱: 龍涎居雞膳食坊 師大創始店
# 地址: 大安區羅斯福路三段135號
# 評分: 3.8
# 價格等級: 2
# --------------------
# 店家 5
# 名稱: 王品牛排 台北羅斯福店
# 地址: 中正區羅斯福路二段9號
# 評分: 4.7
# 價格等級: 3
# --------------------
# 店家 6
# 名稱: Vino Vino Caf'e
# 地址: 大安區師大路80巷2號
# 評分: 3.6
# 價格等級: 2
# --------------------
# 店家 7
# 名稱: KGB Kiwi Gourmet Burgers
# 地址: 大安區師大路114巷5號
# 評分: 4.1
# 價格等級: 2
# --------------------
# 店家 8
# 名稱: 麥當勞-羅斯福餐廳
# 地址: 大安區羅斯福路二段45號
# 評分: 3.9
# 價格等級: 1
# --------------------
# 店家 9
# 名稱: 大隱酒食
# 地址: 大安區永康街65號
# 評分: 3.9
# 價格等級: 2
# --------------------
# 店家 10
# 名稱: 紫藤廬
# 地址: 大安區新生南路三段16巷1號
# 評分: 4.2
# 價格等級: 2
# --------------------
# 店家 11
# 名稱: 樂麵屋 永康店
# 地址: 大安區永康街10巷7號
# 評分: 4.2
# 價格等級: 2
# --------------------
# 店家 12
# 名稱: 瑪莉珍披薩 師大店
# 地址: 大安區浦城街33-9號
# 評分: 4.1
# 價格等級: 2
# --------------------
# 店家 13
# 名稱: 徐羅伐韓國料理
# 地址: 大安區永康街14巷5號
# 評分: 3.5
# 價格等級: 2
# --------------------
# 店家 14
# 名稱: 游壽司麗水店
# 地址: 大安區麗水街7巷7號
# 評分: 4.7
# 價格等級: 2
# --------------------
# 店家 15
# 名稱: Macho Tacos 瑪丘墨式餅舖 (師大 Shida)
# 地址: 大安區師大路93巷1號
# 評分: 4
# 價格等級: 2
# --------------------
# 店家 16
# 名稱: 許記生煎包
# 地址: 大安區師大路39巷12號
# 評分: 3.9
# 價格等級: 1
# --------------------
# 店家 17
# 名稱: 伊洛瓦底
# 地址: 大安區龍泉街76號
# 評分: 3.6
# 價格等級: 1
# --------------------
# 店家 18
# 名稱: 水牛城美式炭烤牛排（古亭）
# 地址: 中正區杭州南路二段94號
# 評分: 4.5
# 價格等級: 2
# --------------------
# 店家 19
# 名稱: 霞飛驛歐法西餐
# 地址: 大安區新生南路三段60巷8號
# 評分: 4.2
# 價格等級: 2
# --------------------
# 店家 20
# 名稱: 青田七六
# 地址: 大安區青田街7巷6號
# 評分: 4.4
# 價格等級: 2
# --------------------
# 店家 21
# 名稱: 六品小館-總店
# 地址: No. 8號, Alley 3, Lane 199, Jinhua Street, Da’an District
# 評分: 4.2
# 價格等級: 2
# --------------------
# 店家 22
# 名稱: Hohomei
# 地址: No. 19-1號, Longquan Street, Da’an District
# 評分: 4
# 價格等級: 1
# --------------------
# 店家 23
# 名稱: 韓記老虎麵食館
# 地址: No. 203號, Jinhua Street, Da’an District
# 評分: 4.1
# 價格等級: 2
# --------------------
# 店家 24
# 名稱: Giguo Taipei Nanchang Branch
# 地址: 2F, No. 216, Section 2, Nanchang Road, Zhongzheng District
# 評分: 4.7
# 價格等級: 2
# --------------------
# 店家 25
# 名稱: SHI YUN Taiwanese Fried Chicken
# 地址: No. 14, Lane 39, Shida Road, Da’an District
# 評分: 4.2
# 價格等級: 1
# --------------------
# 店家 26
# 名稱: SoHo Pasta
# 地址: No. 3號, Lane 60, Section 3, Xinsheng South Road, Da’an District
# 評分: 4.2
# 價格等級: 2
# --------------------
# 店家 27
# 名稱: Witch House
# 地址: No. 7號, Lane 56, Section 3, Xinsheng South Road, Da’an District
# 評分: 4.6
# 價格等級: 2
# --------------------
# 店家 28
# 名稱: Hao Kung Tao Chin Chi Yuan (Da'an)
# 地址: No. 28-1, Yongkang Street, Da’an District
# 評分: 4
# 價格等級: 1
# --------------------
# 店家 29
# 名稱: 雲禾特調小火鍋
# 地址: No. 2號, Yunhe Street, Da’an District
# 評分: 4.1
# 價格等級: 2
# --------------------
# 店家 30
# 名稱: TASTY Taipei Roosevelt Branch
# 地址: 2F, No. 79號, Section 2, Roosevelt Road, Da’an District
# 評分: 4.6
# 價格等級: 2
# --------------------
# 店家 31
# 名稱: Out of India Shida Branch
# 地址: No. 26, Lane 13, Pucheng Street, Da’an District
# 評分: 4.6
# 價格等級: 2
# --------------------
# 店家 32
# 名稱: 晉江茶堂
# 地址: No. 1, Jinjiang Street, Zhongzheng District
# 評分: 4.3
# 價格等級: 2
# --------------------
# 店家 33
# 名稱: Taidian Li Jin Restaurant
# 地址: Lane 75, Section 1, Heping East Road, Da’an District
# 評分: 4
# 價格等級: 2
# --------------------
# 店家 34
# 名稱: 帝拉摩義式餐廳 telamo italian bistro
# 地址: No. 1號, Lane 66, Section 2, Roosevelt Road, Zhongzheng District
# 評分: 4.1
# 價格等級: 2
# --------------------
# 店家 35
# 名稱: Oma's German Delicacies
# 地址: No. 30號, Section 1, Xinhai Road, Da’an District
# 評分: 4.4
# 價格等級: 2
# --------------------
# 店家 36
# 名稱: CHAMONIX Taipei Nanchang Branch
# 地址: 2樓, No. 112, Section 2, Nanchang Road, Zhongzheng District
# 評分: 4.4
# 價格等級: 3
# --------------------
# 店家 37
# 名稱: Yongkang Beef Noodles
# 地址: No. 17號, Lane 31, Section 2, Jinshan South Road, Da’an District
# 評分: 3.8
# 價格等級: 未提供
# --------------------
# 店家 38
# 名稱: Lao Tzang Beef Noodles
# 地址: No. 105號, Aiguo East Road, Da’an District
# 評分: 3.9
# 價格等級: 2
# --------------------
# 店家 39
# 名稱: 恬園餐廳 - 福華國際文教會館
# 地址: No. 30, Section 3, Xinsheng South Road, Da’an District
# 評分: 3.9
# 價格等級: 2
# --------------------
# 店家 40
# 名稱: Oma Ursel's German Bakery
# 地址: No. 221號, Jinhua Street, Da’an District
# 評分: 4.3
# 價格等級: 3
# --------------------
# 店家 41
# 名稱: 豐盛食堂
# 地址: No. 1之3號, Lishui Street, Da’an District
# 評分: 4.3
# 價格等級: 2
# --------------------
# 店家 42
# 名稱: Shengyuan Xiao Long Bao
# 地址: No. 1, Lane 25, Section 2, Hangzhou South Road, Da’an District
# 評分: 3.8
# 價格等級: 2
# --------------------
# 店家 43
# 名稱: Din Tai Fung Xinyi Branch
# 地址: No. 194號, Section 2, Xinyi Road, Da’an District
# 評分: 4.4
# 價格等級: 2
# --------------------
# 店家 44
# 名稱: 佬披薩LAPIZZAitalian
# 地址: No. 8號, Lane 105, Shida Road, Da’an District
# 評分: 4.1
# 價格等級: 2
# --------------------
# 店家 45
# 名稱: 大鵬灣食堂（請先提前電話預約）
# 地址: 1樓, No. 9號, Lane 141, Section 1, Heping East Road, Da’an District
# 評分: 4.1
# 價格等級: 3
# --------------------
# 店家 46
# 名稱: Hong Kong Xin Hua Restaurant
# 地址: No. 48, Yongkang Street, Da’an District
# 評分: 4.1
# 價格等級: 2
# --------------------
# 店家 47
# 名稱: Dongmen Dumplings
# 地址: No. 37號, Lane 31, Section 2, Jinshan South Road, Da’an District
# 評分: 3.7
# 價格等級: 2
# --------------------
# 店家 48
# 名稱: Spring vegetarian restaurant (Daan Branch)
# 地址: 3F, No. 177號, Section 1, Heping East Road, Da’an District
# 評分: 4
# 價格等級: 2
# --------------------
# 店家 49
# 名稱: Rice Café 杓文字
# 地址: No. 7號, Lane 10, Yongkang Street, Da’an District
# 評分: 4.1
# 價格等級: 2
# --------------------
# 店家 50
# 名稱: MOS BURGER Roosevelt Road Shop
# 地址: No. 233, Section 3, Roosevelt Road, Da’an District
# 評分: 4
# 價格等級: 2
# --------------------
# 店家 51
# 名稱: MR. TKK CAFÉ
# 地址: No. 3號, Section 2, Nanchang Road, Zhongzheng District
# 評分: 3.8
# 價格等級: 2
# --------------------
# 店家 52
# 名稱: 甘泉魚麵師大店
# 地址: No. 12號, Lane 59, Shida Road, Da’an District
# 評分: 3.3
# 價格等級: 2
# --------------------
# 店家 53
# 名稱: Lu Sang Restaurant
# 地址: No. 12-5號, Yongkang Street, Da’an District
# 評分: 3.8
# 價格等級: 2
# --------------------
# 店家 54
# 名稱: ROSE HOUSE Yongkang Shop
# 地址: No. 3之1號, Lishui Street, Da’an District
# 評分: 4.2
# 價格等級: 2
# --------------------
# 店家 55
# 名稱: 魚日式料理
# 地址: No. 10, Lane 15, Section 2, Luosifu Road, Da’an District
# 評分: 4.1
# 價格等級: 2
# --------------------
# 店家 56
# 名稱: Sukiya Guting Restaurant
# 地址: No. 50號, Section 2, Roosevelt Road, Zhongzheng District
# 評分: 4.1
# 價格等級: 1
# --------------------
# 店家 57
# 名稱: 阿妹麵店
# 地址: No. 105號, Section 2, Nanchang Road, Zhongzheng District
# 評分: 4
# 價格等級: 未提供
# --------------------
# 店家 58
# 名稱: THANH KY
# 地址: No. 1號, Lane 6, Yongkang Street, Da’an District
# 評分: 3.8
# 價格等級: 2
# --------------------
# 店家 59
# 名稱: 紅葉日式愛好燒
# 地址: No. 4, 晉江街18巷18弄, Zhongzheng District
# 評分: 3.9
# 價格等級: 1
# --------------------
# 店家 60
# 名稱: A.B HOUSE
# 地址: No. 188, Chaozhou Street, Da’an District
# 評分: 4.4
# 價格等級: 2
# --------------------
